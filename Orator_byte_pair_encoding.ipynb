# %%
with open("the_verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()
print("Total number of character:", len(raw_text))
print(raw_text[:100])
# Out:
# Total number of character: 20480
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no g

# %%
import tiktoken
from importlib.metadata import version
print("tiktoken version:", version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
"Hello, do you like tea? <|endoftext|> In the sunlit terraces"
"of someunknownPlace."
)
integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
print(integers)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
strings = tokenizer.decode(integers)
print(strings)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terracesof someunknownPlace.

# %%
unkown_word_test = (
"YEahiknowrightsomecoolLargelanguageMODEls"
)
encoded_unkown_word = tokenizer.encode(unkown_word_test)

# %%
encoded_unkown_word
# Out:
# [48743, 993, 1134, 2197, 28046, 462, 24494, 43, 853, 417, 9000, 49058, 7278]

# %%
decoded_unkown_word = tokenizer.decode(encoded_unkown_word)
decoded_unkown_word
# Out:
# 'YEahiknowrightsomecoolLargelanguageMODEls'
